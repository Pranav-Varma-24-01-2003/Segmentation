# %%
import albumentations as A
# with open("/home/pranav/DeepLearning/new.txt","w") as wr:
#     wr.write("Completed first cell")
# Out:
# /home/pranav/.local/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
import cv2
import random
import albumentations as A
from matplotlib import pyplot as plt
import time
# with open("/home/pranav/DeepLearning/new.txt","a") as wr:
#     wr.write("The second")

# %%
transform = A.Compose([
    A.RandomCrop(width=4500, height=3000, p=1.0),
    A.HorizontalFlip(p=1.0),
    A.VerticalFlip(p=1.0),
    A.Rotate(limit=[60, 240], p=1.0, interpolation=cv2.INTER_NEAREST),
    A.RandomBrightnessContrast(brightness_limit=[-0.2, 0.4], contrast_limit=0.2, p=1.0),
    A.OneOf([
        A.CLAHE (clip_limit=2.0, tile_grid_size=(8, 8), p=0.5),
        A.GridDistortion(p=0.5),
        A.OpticalDistortion(distort_limit=1, shift_limit=0.5, interpolation=cv2.INTER_NEAREST, p=0.5),
    ], p=1.0),
], p=1.0)
# with open("/home/pranav/DeepLearning/new.txt","a") as wr:
#     wr.write("The third")

# %%
def visualize(image, mask, original_image=None, original_mask=None):
    fontsize = 16

    if original_image is None and original_mask is None:
        f, ax = plt.subplots(2, 1, figsize=(16, 16), squeeze=True)
        f.set_tight_layout(h_pad=5, w_pad=5)

        ax[0].imshow(image)
        ax[1].imshow(mask)
    else:
        f, ax = plt.subplots(2, 2, figsize=(16, 16), squeeze=True)
        plt.tight_layout(pad=0.2, w_pad=1.0, h_pad=0.01)

        ax[0, 0].imshow(original_image)
        ax[0, 0].set_title('Original Image', fontsize=fontsize)

        ax[1, 0].imshow(original_mask)
        ax[1, 0].set_title('Original Mask', fontsize=fontsize)

        ax[0, 1].imshow(image)
        ax[0, 1].set_title('Transformed Image', fontsize=fontsize)

        ax[1, 1].imshow(mask)
        ax[1, 1].set_title('Transformed Mask', fontsize=fontsize)

    
        
    plt.savefig('sample_augmented_image.png', facecolor= 'w', transparent= False, bbox_inches= 'tight', dpi= 100)
# with open("/home/pranav/DeepLearning/new.txt","a") as wr:
#     wr.write("The fourth")

# %%
# image = cv2.imread("/home/pranav/DeepLearning/semantic_drone_dataset/training_set/images/040.jpg")
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# mask = cv2.imread("/home/pranav/DeepLearning/semantic_drone_dataset/training_set/gt/semantic/label_images/040.png")
# mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB
#                    )

# transformed = transform(image=image, mask=mask)
# transformed_image = transformed['image']
# transformed_mask = transformed['mask']

# cv2.imwrite('./image.png',cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB))
# cv2.imwrite('./mask.png',cv2.cvtColor(transformed_mask, cv2.COLOR_BGR2RGB))

# visualize(transformed_image, transformed_mask, image, mask)

# %%
images_dir = '/home/pranav/DeepLearning/train_images'
masks_dir = '/home/pranav/DeepLearning/train_masks'
# val_images = 'C:/Users/prana/Deep Learning - Segmentation/val_train_images'
# masksval = "C:/Users/prana/Deep Learning - Segmentation/masksvalimages"
# with open("/home/pranav/DeepLearning/new.txt","a") as wr:
#     wr.write("The third")

# %%
import os
import numpy as np

# %%
file_names = np.sort(os.listdir("/home/pranav/DeepLearning/semantic_drone_dataset/training_set/images")) 
file_names = np.char.split(file_names, '.')
filenames = np.array([])
for i in range(len(file_names)):
    filenames = np.append(filenames, file_names[i][0])

# %%
print(filenames)
for file in filenames:
    print(file)
# Out:
# ['000' '001' '002' '003' '004' '005' '006' '008' '011' '013' '014' '015'
#  '016' '018' '019' '021' '022' '023' '026' '028' '031' '035' '038' '040'
#  '041' '042' '043' '044' '045' '047' '049' '051' '052' '053' '055' '056'
#  '057' '058' '059' '060' '062' '063' '065' '068' '070' '071' '073' '074'
#  '075' '077' '078' '079' '080' '081' '083' '086' '088' '089' '092' '095'
#  '098' '099' '100' '101' '102' '103' '104' '106' '107' '109' '110' '111'
#  '112' '113' '116' '117' '118' '119' '120' '121' '122' '123' '124' '126'
#  '128' '130' '133' '134' '135' '136' '137' '138' '139' '140' '141' '145'
#  '146' '147' '148' '149' '150' '153' '154' '155' '156' '157' '158' '159'
#  '160' '161' '162' '163' '164' '165' '166' '167' '170' '171' '172' '173'
#  '174' '175' '176' '177' '178' '179' '180' '181' '182' '185' '186' '188'
#  '190' '192' '193' '194' '195' '198' '199' '200' '202' '204' '206' '207'
#  '208' '209' '213' '214' '215' '216' '217' '219' '220' '221' '222' '223'
#  '225' '226' '228' '229' '230' '232' '233' '234' '235' '236' '237' '238'
#  '239' '240' '243' '244' '246' '248' '250' '251' '252' '255' '257' '258'
#  '259' '260' '261' '262' '263' '265' '266' '271' '272' '273' '275' '276'
#  '277' '281' '283' '287' '288' '289' '290' '292' '294' '295' '296' '298'
#  '299' '301' '302' '303' '304' '305' '306' '309' '310' '311' '312' '313'
#  '314' '316' '318' '320' '321' '322' '323' '324' '325' '326' '329' '330'
#  '331' '332' '334' '335' '338' '339' '341' '342' '344' '345' '346' '347'
#  '348' '349' '351' '355' '356' '361' '363' '366' '367' '372' '373' '375'
#  '376' '378' '380' '381' '382' '383' '385' '386' '388' '389' '390' '391'
#  '393' '397' '398' '403' '406' '408' '409' '410' '411' '412' '413' '414'
#  '416' '419' '420' '421' '423' '424' '425' '426' '427' '428' '429' '430'
#  '431' '433' '434' '435' '437' '438' '439' '440' '442' '443' '444' '445'
#  '446' '447' '451' '452' '454' '455' '457' '458' '460' '461' '462' '463'
#  '464' '465' '467' '470' '472' '473' '474' '475' '476' '478' '479' '480'
#  '484' '485' '488' '489' '491' '493' '494' '497' '498' '499' '500' '501'
#  '502' '507' '508' '509' '510' '512' '513' '514' '515' '517' '518' '521'
#  '524' '525' '526' '529' '530' '531' '532' '533' '535' '536' '537' '538'
#  '540' '543' '544' '545' '549' '551' '554' '556' '558' '559' '560' '561'
#  '563' '564' '565' '566' '567' '568' '569' '570' '572' '573' '574' '576'
#  '579' '580' '582' '583' '584' '585' '586' '587' '588' '590' '591' '592'
#  '593' '594' '596' '598']
# 000
# 001
# 002
# 003
# 004
# 005
# 006
# 008
# 011
# 013
# 014
# 015
# 016
# 018
# 019
# 021
# 022
# 023
# 026
# 028
# 031
# 035
# 038
# 040
# 041
# 042
# 043
# 044
# 045
# 047
# 049
# 051
# 052
# 053
# 055
# 056
# 057
# 058
# 059
# 060
# 062
# 063
# 065
# 068
# 070
# 071
# 073
# 074
# 075
# 077
# 078
# 079
# 080
# 081
# 083
# 086
# 088
# 089
# 092
# 095
# 098
# 099
# 100
# 101
# 102
# 103
# 104
# 106
# 107
# 109
# 110
# 111
# 112
# 113
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 126
# 128
# 130
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 145
# 146
# 147
# 148
# 149
# 150
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 185
# 186
# 188
# 190
# 192
# 193
# 194
# 195
# 198
# 199
# 200
# 202
# 204
# 206
# 207
# 208
# 209
# 213
# 214
# 215
# 216
# 217
# 219
# 220
# 221
# 222
# 223
# 225
# 226
# 228
# 229
# 230
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 243
# 244
# 246
# 248
# 250
# 251
# 252
# 255
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 265
# 266
# 271
# 272
# 273
# 275
# 276
# 277
# 281
# 283
# 287
# 288
# 289
# 290
# 292
# 294
# 295
# 296
# 298
# 299
# 301
# 302
# 303
# 304
# 305
# 306
# 309
# 310
# 311
# 312
# 313
# 314
# 316
# 318
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 329
# 330
# 331
# 332
# 334
# 335
# 338
# 339
# 341
# 342
# 344
# 345
# 346
# 347
# 348
# 349
# 351
# 355
# 356
# 361
# 363
# 366
# 367
# 372
# 373
# 375
# 376
# 378
# 380
# 381
# 382
# 383
# 385
# 386
# 388
# 389
# 390
# 391
# 393
# 397
# 398
# 403
# 406
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 416
# 419
# 420
# 421
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# 430
# 431
# 433
# 434
# 435
# 437
# 438
# 439
# 440
# 442
# 443
# 444
# 445
# 446
# 447
# 451
# 452
# 454
# 455
# 457
# 458
# 460
# 461
# 462
# 463
# 464
# 465
# 467
# 470
# 472
# 473
# 474
# 475
# 476
# 478
# 479
# 480
# 484
# 485
# 488
# 489
# 491
# 493
# 494
# 497
# 498
# 499
# 500
# 501
# 502
# 507
# 508
# 509
# 510
# 512
# 513
# 514
# 515
# 517
# 518
# 521
# 524
# 525
# 526
# 529
# 530
# 531
# 532
# 533
# 535
# 536
# 537
# 538
# 540
# 543
# 544
# 545
# 549
# 551
# 554
# 556
# 558
# 559
# 560
# 561
# 563
# 564
# 565
# 566
# 567
# 568
# 569
# 570
# 572
# 573
# 574
# 576
# 579
# 580
# 582
# 583
# 584
# 585
# 586
# 587
# 588
# 590
# 591
# 592
# 593
# 594
# 596
# 598

# %%
def augment_dataset(count):
    '''Function for data augmentation
        Input:
            count - total no. of images after augmentation = initial no. of images * count
        Output:
            writes augmented images (input images & segmentation masks) to the working directory
    '''
    i = 0
    for i in range(count):
        for file in filenames:
            img = cv2.imread("/home/pranav/DeepLearning/semantic_drone_dataset/training_set/images/"+file+'.jpg')
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            mask = cv2.imread("/home/pranav/DeepLearning/semantic_drone_dataset/training_set/gt/semantic/label_images/"+file+'.png')
            mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
            transformed = transform(image=img, mask=mask)
            transformed_image = transformed['image']
            transformed_mask = transformed['mask']

            cv2.imwrite('/home/pranav/DeepLearning/train_images/aug_images/aug_{}_'.format(str(i+1))+file+'.jpg',cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB))
            cv2.imwrite('/home/pranav/DeepLearning/train_masks/aug_masks/aug_{}_'.format(str(i+1))+file+'.png',cv2.cvtColor(transformed_mask, cv2.COLOR_BGR2RGB))

# %%
# !mkdir aug_images
# !mkdir aug_masks

# %%
#augment_dataset(4)

# %%
# !pip install keract
# import keract

# %%
import keract
# Out:
# 2024-11-12 18:02:22.518782: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1731414742.537309 1510201 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1731414742.542922 1510201 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-12 18:02:22.562333: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import pickle
import numpy as np
import pandas as pd
from PIL import Image
from IPython.display import SVG
import matplotlib.pyplot as plt
# %matplotlib inline
import os, re, sys, random, shutil, cv2

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import applications, optimizers
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.utils import model_to_dot, plot_model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger, LearningRateScheduler, TensorBoard
from tensorflow.keras.layers import Input, Lambda, Activation, Conv2D, MaxPooling2D, BatchNormalization, Add, concatenate, Conv2DTranspose

# %%
train_images = '/home/pranav/DeepLearning/train_images'
train_masks = '/home/pranav/DeepLearning/train_masks'

# %%
file_names = np.sort(os.listdir(train_images+"/aug_images")) 
file_names = np.char.split(file_names, '.')
filenames = np.array([])
for i in range(len(file_names[:5])):
    filenames = np.append(filenames, file_names[i][0])
print(filenames)
# Out:
# ['aug_1_000' 'aug_1_001' 'aug_1_002' 'aug_1_003' 'aug_1_004']

# %%
# def show_data(files, original_images_dir, label_images_dir):

#     for file in files:
#         fig, axs = plt.subplots(1, 2, figsize=(20, 10), constrained_layout=True)

#         axs[0].imshow(Image.open(original_images_dir+"/aug_images/"+str(file)+'.jpg'))
#         axs[0].set_title('Original Image', fontdict = {'fontsize':20})
#         axs[0].set_xticks(np.arange(0, 6500, 1000))
#         axs[0].set_yticks(np.arange(0, 4500, 1000))
#         axs[0].grid(False)
#         axs[0].axis(True)

#         semantic_label_image = Image.open(label_images_dir+"/aug_masks/"+str(file)+'.png')
#         semantic_label_image = np.asarray(semantic_label_image)
#         axs[1].imshow(semantic_label_image)
#         axs[1].set_title('Semantic Segmentation Mask', fontdict = {'fontsize':20})
#         axs[1].set_xticks(np.arange(0, 6500, 1000))
#         axs[1].set_yticks(np.arange(0, 4500, 1000))
#         axs[1].grid(False)
#         axs[1].axis(True)

#         plt.savefig('image_'+file, facecolor= 'w', transparent= False, bbox_inches= 'tight', dpi= 100)
#         plt.show()
    
# show_data(filenames[:5], train_images, train_masks)

# %%
augmented_files = ['092','118', '228', '277', '376']

def show_augmented_images(files, original_images_dir):
    for file in files:
        fig, axs = plt.subplots(1, 5, figsize=(30, 6), constrained_layout=True)
        for i in range(5):
            if i == 0:
                axs[i].imshow(Image.open(original_images_dir+str(file)+'.jpg'))
                axs[i].set_title('Original Image: {}.jpg'.format(file), fontdict = {'fontsize':20})
                axs[i].set_xticks(np.arange(0, 6500, 1000))
                axs[i].set_yticks(np.arange(0, 4500, 1000))
                axs[i].grid(False)
                axs[i].axis(True)
            else:
                axs[i].imshow(Image.open("C:/Users/prana/Deep Learning - Segmentation/aug_images/"+'aug_'+str(i)+'_'+str(file)+'.jpg'))
                axs[i].set_title('Augmented Image: aug_'+str(i)+'_'+str(file)+'.jpg', fontdict = {'fontsize':20})
                axs[i].set_xticks(np.arange(0, 4500, 1000))
                axs[i].set_yticks(np.arange(0, 3001, 1000))
                axs[i].grid(False)
                axs[i].axis(True)

        plt.savefig('aug_image_'+file, facecolor= 'w', transparent= False, bbox_inches= 'tight', dpi= 100)
        plt.show()
    
def show_augmented_masks(files, label_images_dir):
    for file in files:
        fig, axs = plt.subplots(1, 5, figsize=(30, 6), constrained_layout=True)
        for i in range(5):
            if i == 0:
                axs[i].imshow(Image.open(label_images_dir+str(file)+'.png'))
                axs[i].set_title('Original Mask: {}.png'.format(file), fontdict = {'fontsize':20})
                axs[i].set_xticks(np.arange(0, 6500, 1000))
                axs[i].set_yticks(np.arange(0, 4500, 1000))
                axs[i].grid(False)
                axs[i].axis(True)
            else:
                axs[i].imshow(Image.open("C:/Users/prana/Deep Learning - Segmentation/aug_masks/"+"aug_"+str(i)+'_'+str(file)+'.png'))
                axs[i].set_title('Augmented Mask: aug_'+str(i)+'_'+str(file)+'.png', fontdict = {'fontsize':20})
                axs[i].set_xticks(np.arange(0, 4500, 1000))
                axs[i].set_yticks(np.arange(0, 3001, 1000))
                axs[i].grid(False)
                axs[i].axis(True)

        plt.savefig('aug_mask_'+file, facecolor= 'w', transparent= False, bbox_inches= 'tight', dpi= 100)
        plt.show()

# %%
# show_augmented_images(augmented_files, train_images)
# show_augmented_masks(augmented_files, train_masks)
# print(train_images)
# print(train_masks)

# %%
class_dict_df = pd.read_csv("/home/pranav/DeepLearning/semantic_drone_dataset/training_set/gt/semantic/class_dict.csv", index_col=False, skipinitialspace=True)
print(class_dict_df["name"])
# Out:
# 0       unlabeled
# 1      paved-area
# 2            dirt
# 3           grass
# 4          gravel
# 5           water
# 6           rocks
# 7            pool
# 8      vegetation
# 9            roof
# 10           wall
# 11         window
# 12           door
# 13          fence
# 14     fence-pole
# 15         person
# 16            dog
# 17            car
# 18        bicycle
# 19           tree
# 20      bald-tree
# 21      ar-marker
# 22       obstacle
# 23    conflicting
# Name: name, dtype: object

# %%
label_names= list(class_dict_df.name)
label_codes = []
r= np.asarray(class_dict_df.r)
g= np.asarray(class_dict_df.g)
b= np.asarray(class_dict_df.b)

for i in range(len(class_dict_df)):
    label_codes.append(tuple([r[i], g[i], b[i]]))
    
label_codes[:5], label_names[:5]
# Out:
# ([(np.int64(0), np.int64(0), np.int64(0)),
#   (np.int64(128), np.int64(64), np.int64(128)),
#   (np.int64(130), np.int64(76), np.int64(0)),
#   (np.int64(0), np.int64(102), np.int64(0)),
#   (np.int64(112), np.int64(103), np.int64(87))],
#  ['unlabeled', 'paved-area', 'dirt', 'grass', 'gravel'])

# %%
label_codes, label_names
# Out:
# ([(np.int64(0), np.int64(0), np.int64(0)),
#   (np.int64(128), np.int64(64), np.int64(128)),
#   (np.int64(130), np.int64(76), np.int64(0)),
#   (np.int64(0), np.int64(102), np.int64(0)),
#   (np.int64(112), np.int64(103), np.int64(87)),
#   (np.int64(28), np.int64(42), np.int64(168)),
#   (np.int64(48), np.int64(41), np.int64(30)),
#   (np.int64(0), np.int64(50), np.int64(89)),
#   (np.int64(107), np.int64(142), np.int64(35)),
#   (np.int64(70), np.int64(70), np.int64(70)),
#   (np.int64(102), np.int64(102), np.int64(156)),
#   (np.int64(254), np.int64(228), np.int64(12)),
#   (np.int64(254), np.int64(148), np.int64(12)),
#   (np.int64(190), np.int64(153), np.int64(153)),
#   (np.int64(153), np.int64(153), np.int64(153)),
#   (np.int64(255), np.int64(22), np.int64(96)),
#   (np.int64(102), np.int64(51), np.int64(0)),
#   (np.int64(9), np.int64(143), np.int64(150)),
#   (np.int64(119), np.int64(11), np.int64(32)),
#   (np.int64(51), np.int64(51), np.int64(0)),
#   (np.int64(190), np.int64(250), np.int64(190)),
#   (np.int64(112), np.int64(150), np.int64(146)),
#   (np.int64(2), np.int64(135), np.int64(115)),
#   (np.int64(255), np.int64(0), np.int64(0))],
#  ['unlabeled',
#   'paved-area',
#   'dirt',
#   'grass',
#   'gravel',
#   'water',
#   'rocks',
#   'pool',
#   'vegetation',
#   'roof',
#   'wall',
#   'window',
#   'door',
#   'fence',
#   'fence-pole',
#   'person',
#   'dog',
#   'car',
#   'bicycle',
#   'tree',
#   'bald-tree',
#   'ar-marker',
#   'obstacle',
#   'conflicting'])

# %%
code2id = {v:k for k,v in enumerate(label_codes)}
id2code = {k:v for k,v in enumerate(label_codes)}

name2id = {v:k for k,v in enumerate(label_names)}
id2name = {k:v for k,v in enumerate(label_names)}

# %%
def rgb_to_onehot(rgb_image, colormap = id2code):
    '''Function to one hot encode RGB mask labels
        Inputs: 
            rgb_image - image matrix (eg. 256 x 256 x 3 dimension numpy ndarray)
            colormap - dictionary of color to label id
        Output: One hot encoded image of dimensions (height x width x num_classes) where num_classes = len(colormap)
    '''
    num_classes = len(colormap)
    shape = rgb_image.shape[:2]+(num_classes,)
    encoded_image = np.zeros( shape, dtype=np.int8 )
    for i, cls in enumerate(colormap):
        encoded_image[:,:,i] = np.all(rgb_image.reshape( (-1,3) ) == colormap[i], axis=1).reshape(shape[:2])
    return encoded_image


def onehot_to_rgb(onehot, colormap = id2code):
    '''Function to decode encoded mask labels
        Inputs: 
            onehot - one hot encoded image matrix (height x width x num_classes)
            colormap - dictionary of color to label id
        Output: Decoded RGB image (height x width x 3) 
    '''
    single_layer = np.argmax(onehot, axis=-1)
    output = np.zeros( onehot.shape[:2]+(3,) )
    for k in colormap.keys():
        output[single_layer==k] = colormap[k]
    return np.uint8(output)

# %%
# Normalizing only frame images, since masks contain label info
data_gen_args = dict(rescale=1./255)
mask_gen_args = dict()

train_frames_datagen = ImageDataGenerator(**data_gen_args)
train_masks_datagen = ImageDataGenerator(**mask_gen_args)
val_frames_datagen = ImageDataGenerator(**data_gen_args)
val_masks_datagen = ImageDataGenerator(**mask_gen_args)
# Seed defined for aligning images and their masks
seed = 1

# %%
def TrainAugmentGenerator(train_images_dir, train_masks_dir, seed = 1, batch_sizess = 8, target_sizess = (512, 512)):
    '''Train Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
            train_images_dir - train images directory
            train_masks_dir - train masks directory
            target_size - tuple of integers (height, width)
            
        Output: Decoded RGB image (height x width x 3) 
    '''
    train_image_generator = train_frames_datagen.flow_from_directory(
   train_images_dir,
    batch_size= batch_sizess, 
    seed = seed, 
    target_size = target_sizess)

    train_mask_generator = train_masks_datagen.flow_from_directory(
    train_masks_dir,
    batch_size = batch_sizess, 
    seed = seed, 
    target_size = target_sizess)

    while True:
        X1i = next(train_image_generator)
        X2i = next(train_mask_generator)
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        if(X1i[0] is None or mask_encoded is None):
            print("I am sending Null object to you")
        yield X1i[0], np.asarray(mask_encoded)

def ValAugmentGenerator(val_images_dr, masksvaldr, seed = 1, batch_sizess = 8, target_sizess = (512, 512)):
    '''Train Image data generator
        Inputs: 
            seed - seed provided to the flow_from_directory function to ensure aligned data flow
            batch_size - number of images to import at a time
            train_images_dir - train images directory
            train_masks_dir - train masks directory
            target_size - tuple of integers (height, width)
            
        Output: Decoded RGB image (height x width x 3) 
    '''
    val_image_generator = val_frames_datagen.flow_from_directory(
   val_images_dr,
    batch_size= batch_sizess, 
    seed = seed, 
    target_size = target_sizess)

    val_mask_generator = val_masks_datagen.flow_from_directory(
    masksvaldr,
    batch_size = batch_sizess, 
    seed = seed, 
    target_size = target_sizess)

    while True:
        X1i = next(val_image_generator)
        X2i = next(val_mask_generator)
        
        #One hot encoding RGB images
        mask_encoded = [rgb_to_onehot(X2i[0][x,:,:,:], id2code) for x in range(X2i[0].shape[0])]
        if(X1i[0] is None or mask_encoded is None):
            print("I am sending Null object to you")
        yield X1i[0], np.asarray(mask_encoded)

# %%
# !mkdir pretrained_weight

# %%
import numpy as np
import os
batch_size = 8
num_train_samples = len(np.sort(os.listdir(train_images)))
steps_per_epoch = np.ceil(float(num_train_samples) / float(batch_size))
print('steps_per_epoch: ', steps_per_epoch)
print(train_images)
print(train_masks)
with open("/home/pranav/DeepLearning/new.txt","a") as wr:
    wr.write("The sixth")
# Out:
# steps_per_epoch:  1.0
# /home/pranav/DeepLearning/train_images
# /home/pranav/DeepLearning/train_masks

# %%
import tensorflow as tf

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers, models

from tensorflow.keras import backend as K
# def dice_score(y_true, y_pred, smooth=1e-6):
#     # Convert y_pred from probabilities to class predictions
#      tf.print(y_true_f.shape)
#     tf.print(y_pred_f.shape)
#     y_pred_classes = tf.argmax(y_pred, axis=-1)

#     # Convert y_true to the same type and shape as y_pred_classes
#     y_true = tf.cast(y_true, tf.int64)
#     print(y_true)
#     print(y_pred_classes)
#     # Ensure both y_true and y_pred_classes have the same shape (flatten them)
#     y_true_f = tf.reshape(y_true, [-1])
#     y_pred_f = tf.reshape(y_pred_classes, [-1])

#     # Calculate the Dice score
#     intersection = tf.reduce_sum(tf.cast(y_true_f == y_pred_f, tf.float32))
#     dice = (2. * intersection + smooth) / (tf.reduce_sum(tf.cast(y_true_f != -1, tf.float32)) + 
#                                             tf.reduce_sum(tf.cast(y_pred_f != -1, tf.float32)) + smooth)
#     print(y_true_f.shape)
#     print(y_pred_f.shape)
#     return dice
# def simplemetric(y_true, y_pred):
#     return tf.constant(0.5)  
def dice_coef(y_true, y_pred):
    return (2. * K.sum(y_true * y_pred) + 1.) / (K.sum(y_true) + K.sum(y_pred) + 1.)

# class SimpleMetric(tf.keras.metrics.Metric):
#     def __init__(self, name='simple_constant_metric', **kwargs):
#         super(SimpleConstantMetric, self).__init__(name=name, **kwargs)
#         self.value = self.add_weight(name="value", initializer="zeros")

#     def update_state(self, y_true, y_pred, sample_weight=None):
#         # Update state with the constant value (0.5)
#         self.value.assign(0.5)

#     def result(self):
#         # Return the current value of the metric
#         return self.value

#     def reset_states(self):
#         # Reset metric state
#         self.value.assign(0.0)
class DiceCoefficient(tf.keras.metrics.Metric):
    def __init__(self, name='dice_coefficient', smooth=1e-6, **kwargs):
        super(DiceCoefficient, self).__init__(name=name, **kwargs)
        self.smooth = smooth
        self.intersection = self.add_weight(name='intersection', initializer='zeros')
        self.union = self.add_weight(name='union', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Flatten the tensors to calculate the Dice coefficient
        y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
        y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
        
        # Calculate the intersection (true positives)
        intersection = tf.reduce_sum(y_true_f * y_pred_f)
        
        # Calculate the union (sum of both sets)
        union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
        
        # Update the total intersection and union state
        self.intersection.assign_add(intersection)
        self.union.assign_add(union)

    def result(self):
        # Return the Dice coefficient
        dice = (2. * self.intersection + self.smooth) / (self.union + self.smooth)
        return dice  # This will return a 'tf.Tensor' (EagerTensor in eager mode)

    def reset_states(self):
        # Reset the intersection and union for the next epoch
        self.intersection.assign(0.0)
        self.union.assign(0.0)
    def get_config(self):  # Renamed from `get_config()` to `get_dice_config()`
        dt = super(DiceCoefficient, self).get_config()
        dt.update({
            "smooth": self.smooth,
        })
        return dt   
class TimeHistory(tf.keras.callbacks.Callback):
    def __init__(self, file_path="epoch_times.txt"):
        super(TimeHistory, self).__init__()
        self.file_path = file_path  # Custom file path for saving the times

    def on_train_begin(self, logs=None):
        self.epoch_times = []  # Initialize a list to store times for each epoch

    def on_epoch_begin(self, epoch, logs=None):
        self.start_time = time.time()  # Record the start time of the epoch

    def on_epoch_end(self, epoch, logs=None):
        epoch_duration = time.time() - self.start_time  # Calculate the duration of the epoch
        self.epoch_times.append(epoch_duration)  # Append to the list

    def on_train_end(self, logs=None):
        # Ensure the directory exists
        os.makedirs(os.path.dirname(self.file_path), exist_ok=True)
        
        # Store the epoch times list in the specified file path
        with open(self.file_path, "w") as file:
            file.write(str(self.epoch_times))
        print(f"Epoch times saved to '{self.file_path}'.")        
def efficient_b0(input_shape=(512, 512, 3), num_classes=24, trainable_encoder=False, lr_init=0.001):
    """
    Build a U-Net model with EfficientNet-B0 as the encoder.
    
    Parameters:
        input_shape (tuple): Shape of the input images (default is 512x512x3).
        num_classes (int): Number of output classes for segmentation (default is 24).
        trainable_encoder (bool): Whether to fine-tune the encoder (default is False).
        lr_init (float): Initial learning rate for the optimizer (default is 0.001).
    
    Returns:
        tf.keras.Model: The compiled U-Net model with EfficientNet-B0 as the encoder.
    """
    # Load EfficientNet-B0 as the encoder
    efficientnet_encoder = EfficientNetB0(include_top=False, weights='imagenet', input_shape=input_shape)
    efficientnet_encoder.trainable = trainable_encoder

    # Encoder outputs at different levels
    encoder_outputs = [
        efficientnet_encoder.get_layer('block2a_expand_activation').output,  # 256x256
        efficientnet_encoder.get_layer('block3a_expand_activation').output,  # 128x128
        efficientnet_encoder.get_layer('block4a_expand_activation').output,  # 64x64
        efficientnet_encoder.get_layer('block6a_expand_activation').output,  # 32x32
        efficientnet_encoder.get_layer('top_activation').output,            # 16x16
    ]

    # Decoder path
    x = encoder_outputs[-1]  # Start from the bottleneck (16x16x1280)

    # Upsample to 32x32
    x = layers.Conv2D(512, (3, 3), padding='same', activation='relu')(x)
    x = layers.UpSampling2D((2, 2))(x)  # (32x32x512)
    x = layers.Concatenate()([x, encoder_outputs[-2]])  # Skip connection

    # Upsample to 64x64
    x = layers.Conv2D(256, (3, 3), padding='same', activation='relu')(x)
    x = layers.UpSampling2D((2, 2))(x)  # (64x64x256)
    x = layers.Concatenate()([x, encoder_outputs[-3]])  # Skip connection

    # Upsample to 128x128
    x = layers.Conv2D(128, (3, 3), padding='same', activation='relu')(x)
    x = layers.UpSampling2D((2, 2))(x)  # (128x128x128)
    x = layers.Concatenate()([x, encoder_outputs[-4]])  # Skip connection

    # Upsample to 256x256
    x = layers.Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    x = layers.UpSampling2D((2, 2))(x)  # (256x256x64)
    x = layers.Concatenate()([x, encoder_outputs[-5]])  # Skip connection

    # Upsample to 512x512
    x = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(x)
    x = layers.UpSampling2D((2, 2))(x)  # (512x512x32)

    # Final segmentation layer
    output = layers.Conv2D(num_classes, (3, 3), padding='same',activation='softmax')(x)  # num_classes channels

    # Build the model
    model = models.Model(inputs=efficientnet_encoder.input, outputs=output)

    # Compile the model with the specified initial learning rate
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_init)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
print(train_images)
print(train_masks)
os.environ['XLA_FLAGS'] = '--xla_gpu_strict_conv_algorithm_picker=false'
os.environ["CUDA_VISIBLE_DEVICES"] = "1,2,3,4,5,6,7"
print("hh")
print("hhh")
# Out:
# /home/pranav/DeepLearning/train_images
# /home/pranav/DeepLearning/train_masks
# hh
# hhh

# %%
vgg16_unet = efficient_b0(num_classes = 24, input_shape = (512, 512, 3), lr_init = 0.0001)
#vgg16_unet.load_weights("vgg16_unet_model.keras")
#vgg16_unet=tf.keras.models.load_model("mobilenet22.keras",custom_objects={'DiceCoefficient': DiceCoefficient})
#vgg16_unet=tf.keras.models.load_model("vgg16_unet_model.keras",custom_objects={'DiceCoefficient':DiceCoefficient})
vgg16_unet.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 512, 512, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ rescaling_2 (Rescaling)       │ (None, 512, 512, 3)       │               0 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ normalization_1               │ (None, 512, 512, 3)       │               7 │ rescaling_2[0][0]          │
# │ (Normalization)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ rescaling_3 (Rescaling)       │ (None, 512, 512, 3)       │               0 │ normalization_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ stem_conv_pad (ZeroPadding2D) │ (None, 513, 513, 3)       │               0 │ rescaling_3[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ stem_conv (Conv2D)            │ (None, 256, 256, 32)      │             864 │ stem_conv_pad[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ stem_bn (BatchNormalization)  │ (None, 256, 256, 32)      │             128 │ stem_conv[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ stem_activation (Activation)  │ (None, 256, 256, 32)      │               0 │ stem_bn[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_dwconv                │ (None, 256, 256, 32)      │             288 │ stem_activation[0][0]      │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_bn                    │ (None, 256, 256, 32)      │             128 │ block1a_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_activation            │ (None, 256, 256, 32)      │               0 │ block1a_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_se_squeeze            │ (None, 32)                │               0 │ block1a_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_se_reshape (Reshape)  │ (None, 1, 1, 32)          │               0 │ block1a_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_se_reduce (Conv2D)    │ (None, 1, 1, 8)           │             264 │ block1a_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_se_expand (Conv2D)    │ (None, 1, 1, 32)          │             288 │ block1a_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_se_excite (Multiply)  │ (None, 256, 256, 32)      │               0 │ block1a_activation[0][0],  │
# │                               │                           │                 │ block1a_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_project_conv (Conv2D) │ (None, 256, 256, 16)      │             512 │ block1a_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1a_project_bn            │ (None, 256, 256, 16)      │              64 │ block1a_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_expand_conv (Conv2D)  │ (None, 256, 256, 96)      │           1,536 │ block1a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_expand_bn             │ (None, 256, 256, 96)      │             384 │ block2a_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_expand_activation     │ (None, 256, 256, 96)      │               0 │ block2a_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_dwconv_pad            │ (None, 257, 257, 96)      │               0 │ block2a_expand_activation… │
# │ (ZeroPadding2D)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_dwconv                │ (None, 128, 128, 96)      │             864 │ block2a_dwconv_pad[0][0]   │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_bn                    │ (None, 128, 128, 96)      │             384 │ block2a_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_activation            │ (None, 128, 128, 96)      │               0 │ block2a_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_se_squeeze            │ (None, 96)                │               0 │ block2a_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_se_reshape (Reshape)  │ (None, 1, 1, 96)          │               0 │ block2a_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_se_reduce (Conv2D)    │ (None, 1, 1, 4)           │             388 │ block2a_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_se_expand (Conv2D)    │ (None, 1, 1, 96)          │             480 │ block2a_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_se_excite (Multiply)  │ (None, 128, 128, 96)      │               0 │ block2a_activation[0][0],  │
# │                               │                           │                 │ block2a_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_project_conv (Conv2D) │ (None, 128, 128, 24)      │           2,304 │ block2a_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2a_project_bn            │ (None, 128, 128, 24)      │              96 │ block2a_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_expand_conv (Conv2D)  │ (None, 128, 128, 144)     │           3,456 │ block2a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_expand_bn             │ (None, 128, 128, 144)     │             576 │ block2b_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_expand_activation     │ (None, 128, 128, 144)     │               0 │ block2b_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_dwconv                │ (None, 128, 128, 144)     │           1,296 │ block2b_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_bn                    │ (None, 128, 128, 144)     │             576 │ block2b_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_activation            │ (None, 128, 128, 144)     │               0 │ block2b_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_se_squeeze            │ (None, 144)               │               0 │ block2b_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_se_reshape (Reshape)  │ (None, 1, 1, 144)         │               0 │ block2b_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_se_reduce (Conv2D)    │ (None, 1, 1, 6)           │             870 │ block2b_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_se_expand (Conv2D)    │ (None, 1, 1, 144)         │           1,008 │ block2b_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_se_excite (Multiply)  │ (None, 128, 128, 144)     │               0 │ block2b_activation[0][0],  │
# │                               │                           │                 │ block2b_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_project_conv (Conv2D) │ (None, 128, 128, 24)      │           3,456 │ block2b_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_project_bn            │ (None, 128, 128, 24)      │              96 │ block2b_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_drop (Dropout)        │ (None, 128, 128, 24)      │               0 │ block2b_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2b_add (Add)             │ (None, 128, 128, 24)      │               0 │ block2b_drop[0][0],        │
# │                               │                           │                 │ block2a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_expand_conv (Conv2D)  │ (None, 128, 128, 144)     │           3,456 │ block2b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_expand_bn             │ (None, 128, 128, 144)     │             576 │ block3a_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_expand_activation     │ (None, 128, 128, 144)     │               0 │ block3a_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_dwconv_pad            │ (None, 131, 131, 144)     │               0 │ block3a_expand_activation… │
# │ (ZeroPadding2D)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_dwconv                │ (None, 64, 64, 144)       │           3,600 │ block3a_dwconv_pad[0][0]   │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_bn                    │ (None, 64, 64, 144)       │             576 │ block3a_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_activation            │ (None, 64, 64, 144)       │               0 │ block3a_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_se_squeeze            │ (None, 144)               │               0 │ block3a_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_se_reshape (Reshape)  │ (None, 1, 1, 144)         │               0 │ block3a_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_se_reduce (Conv2D)    │ (None, 1, 1, 6)           │             870 │ block3a_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_se_expand (Conv2D)    │ (None, 1, 1, 144)         │           1,008 │ block3a_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_se_excite (Multiply)  │ (None, 64, 64, 144)       │               0 │ block3a_activation[0][0],  │
# │                               │                           │                 │ block3a_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_project_conv (Conv2D) │ (None, 64, 64, 40)        │           5,760 │ block3a_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3a_project_bn            │ (None, 64, 64, 40)        │             160 │ block3a_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_expand_conv (Conv2D)  │ (None, 64, 64, 240)       │           9,600 │ block3a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_expand_bn             │ (None, 64, 64, 240)       │             960 │ block3b_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_expand_activation     │ (None, 64, 64, 240)       │               0 │ block3b_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_dwconv                │ (None, 64, 64, 240)       │           6,000 │ block3b_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_bn                    │ (None, 64, 64, 240)       │             960 │ block3b_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_activation            │ (None, 64, 64, 240)       │               0 │ block3b_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_se_squeeze            │ (None, 240)               │               0 │ block3b_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_se_reshape (Reshape)  │ (None, 1, 1, 240)         │               0 │ block3b_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_se_reduce (Conv2D)    │ (None, 1, 1, 10)          │           2,410 │ block3b_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_se_expand (Conv2D)    │ (None, 1, 1, 240)         │           2,640 │ block3b_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_se_excite (Multiply)  │ (None, 64, 64, 240)       │               0 │ block3b_activation[0][0],  │
# │                               │                           │                 │ block3b_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_project_conv (Conv2D) │ (None, 64, 64, 40)        │           9,600 │ block3b_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_project_bn            │ (None, 64, 64, 40)        │             160 │ block3b_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_drop (Dropout)        │ (None, 64, 64, 40)        │               0 │ block3b_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3b_add (Add)             │ (None, 64, 64, 40)        │               0 │ block3b_drop[0][0],        │
# │                               │                           │                 │ block3a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_expand_conv (Conv2D)  │ (None, 64, 64, 240)       │           9,600 │ block3b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_expand_bn             │ (None, 64, 64, 240)       │             960 │ block4a_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_expand_activation     │ (None, 64, 64, 240)       │               0 │ block4a_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_dwconv_pad            │ (None, 65, 65, 240)       │               0 │ block4a_expand_activation… │
# │ (ZeroPadding2D)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_dwconv                │ (None, 32, 32, 240)       │           2,160 │ block4a_dwconv_pad[0][0]   │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_bn                    │ (None, 32, 32, 240)       │             960 │ block4a_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_activation            │ (None, 32, 32, 240)       │               0 │ block4a_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_se_squeeze            │ (None, 240)               │               0 │ block4a_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_se_reshape (Reshape)  │ (None, 1, 1, 240)         │               0 │ block4a_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_se_reduce (Conv2D)    │ (None, 1, 1, 10)          │           2,410 │ block4a_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_se_expand (Conv2D)    │ (None, 1, 1, 240)         │           2,640 │ block4a_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_se_excite (Multiply)  │ (None, 32, 32, 240)       │               0 │ block4a_activation[0][0],  │
# │                               │                           │                 │ block4a_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_project_conv (Conv2D) │ (None, 32, 32, 80)        │          19,200 │ block4a_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4a_project_bn            │ (None, 32, 32, 80)        │             320 │ block4a_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_expand_conv (Conv2D)  │ (None, 32, 32, 480)       │          38,400 │ block4a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_expand_bn             │ (None, 32, 32, 480)       │           1,920 │ block4b_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_expand_activation     │ (None, 32, 32, 480)       │               0 │ block4b_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_dwconv                │ (None, 32, 32, 480)       │           4,320 │ block4b_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_bn                    │ (None, 32, 32, 480)       │           1,920 │ block4b_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_activation            │ (None, 32, 32, 480)       │               0 │ block4b_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_se_squeeze            │ (None, 480)               │               0 │ block4b_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_se_reshape (Reshape)  │ (None, 1, 1, 480)         │               0 │ block4b_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_se_reduce (Conv2D)    │ (None, 1, 1, 20)          │           9,620 │ block4b_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_se_expand (Conv2D)    │ (None, 1, 1, 480)         │          10,080 │ block4b_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_se_excite (Multiply)  │ (None, 32, 32, 480)       │               0 │ block4b_activation[0][0],  │
# │                               │                           │                 │ block4b_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_project_conv (Conv2D) │ (None, 32, 32, 80)        │          38,400 │ block4b_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_project_bn            │ (None, 32, 32, 80)        │             320 │ block4b_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_drop (Dropout)        │ (None, 32, 32, 80)        │               0 │ block4b_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4b_add (Add)             │ (None, 32, 32, 80)        │               0 │ block4b_drop[0][0],        │
# │                               │                           │                 │ block4a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_expand_conv (Conv2D)  │ (None, 32, 32, 480)       │          38,400 │ block4b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_expand_bn             │ (None, 32, 32, 480)       │           1,920 │ block4c_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_expand_activation     │ (None, 32, 32, 480)       │               0 │ block4c_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_dwconv                │ (None, 32, 32, 480)       │           4,320 │ block4c_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_bn                    │ (None, 32, 32, 480)       │           1,920 │ block4c_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_activation            │ (None, 32, 32, 480)       │               0 │ block4c_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_se_squeeze            │ (None, 480)               │               0 │ block4c_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_se_reshape (Reshape)  │ (None, 1, 1, 480)         │               0 │ block4c_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_se_reduce (Conv2D)    │ (None, 1, 1, 20)          │           9,620 │ block4c_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_se_expand (Conv2D)    │ (None, 1, 1, 480)         │          10,080 │ block4c_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_se_excite (Multiply)  │ (None, 32, 32, 480)       │               0 │ block4c_activation[0][0],  │
# │                               │                           │                 │ block4c_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_project_conv (Conv2D) │ (None, 32, 32, 80)        │          38,400 │ block4c_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_project_bn            │ (None, 32, 32, 80)        │             320 │ block4c_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_drop (Dropout)        │ (None, 32, 32, 80)        │               0 │ block4c_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4c_add (Add)             │ (None, 32, 32, 80)        │               0 │ block4c_drop[0][0],        │
# │                               │                           │                 │ block4b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_expand_conv (Conv2D)  │ (None, 32, 32, 480)       │          38,400 │ block4c_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_expand_bn             │ (None, 32, 32, 480)       │           1,920 │ block5a_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_expand_activation     │ (None, 32, 32, 480)       │               0 │ block5a_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_dwconv                │ (None, 32, 32, 480)       │          12,000 │ block5a_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_bn                    │ (None, 32, 32, 480)       │           1,920 │ block5a_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_activation            │ (None, 32, 32, 480)       │               0 │ block5a_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_se_squeeze            │ (None, 480)               │               0 │ block5a_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_se_reshape (Reshape)  │ (None, 1, 1, 480)         │               0 │ block5a_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_se_reduce (Conv2D)    │ (None, 1, 1, 20)          │           9,620 │ block5a_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_se_expand (Conv2D)    │ (None, 1, 1, 480)         │          10,080 │ block5a_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_se_excite (Multiply)  │ (None, 32, 32, 480)       │               0 │ block5a_activation[0][0],  │
# │                               │                           │                 │ block5a_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_project_conv (Conv2D) │ (None, 32, 32, 112)       │          53,760 │ block5a_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5a_project_bn            │ (None, 32, 32, 112)       │             448 │ block5a_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_expand_conv (Conv2D)  │ (None, 32, 32, 672)       │          75,264 │ block5a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_expand_bn             │ (None, 32, 32, 672)       │           2,688 │ block5b_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_expand_activation     │ (None, 32, 32, 672)       │               0 │ block5b_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_dwconv                │ (None, 32, 32, 672)       │          16,800 │ block5b_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_bn                    │ (None, 32, 32, 672)       │           2,688 │ block5b_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_activation            │ (None, 32, 32, 672)       │               0 │ block5b_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_se_squeeze            │ (None, 672)               │               0 │ block5b_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_se_reshape (Reshape)  │ (None, 1, 1, 672)         │               0 │ block5b_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_se_reduce (Conv2D)    │ (None, 1, 1, 28)          │          18,844 │ block5b_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_se_expand (Conv2D)    │ (None, 1, 1, 672)         │          19,488 │ block5b_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_se_excite (Multiply)  │ (None, 32, 32, 672)       │               0 │ block5b_activation[0][0],  │
# │                               │                           │                 │ block5b_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_project_conv (Conv2D) │ (None, 32, 32, 112)       │          75,264 │ block5b_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_project_bn            │ (None, 32, 32, 112)       │             448 │ block5b_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_drop (Dropout)        │ (None, 32, 32, 112)       │               0 │ block5b_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5b_add (Add)             │ (None, 32, 32, 112)       │               0 │ block5b_drop[0][0],        │
# │                               │                           │                 │ block5a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_expand_conv (Conv2D)  │ (None, 32, 32, 672)       │          75,264 │ block5b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_expand_bn             │ (None, 32, 32, 672)       │           2,688 │ block5c_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_expand_activation     │ (None, 32, 32, 672)       │               0 │ block5c_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_dwconv                │ (None, 32, 32, 672)       │          16,800 │ block5c_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_bn                    │ (None, 32, 32, 672)       │           2,688 │ block5c_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_activation            │ (None, 32, 32, 672)       │               0 │ block5c_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_se_squeeze            │ (None, 672)               │               0 │ block5c_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_se_reshape (Reshape)  │ (None, 1, 1, 672)         │               0 │ block5c_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_se_reduce (Conv2D)    │ (None, 1, 1, 28)          │          18,844 │ block5c_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_se_expand (Conv2D)    │ (None, 1, 1, 672)         │          19,488 │ block5c_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_se_excite (Multiply)  │ (None, 32, 32, 672)       │               0 │ block5c_activation[0][0],  │
# │                               │                           │                 │ block5c_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_project_conv (Conv2D) │ (None, 32, 32, 112)       │          75,264 │ block5c_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_project_bn            │ (None, 32, 32, 112)       │             448 │ block5c_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_drop (Dropout)        │ (None, 32, 32, 112)       │               0 │ block5c_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5c_add (Add)             │ (None, 32, 32, 112)       │               0 │ block5c_drop[0][0],        │
# │                               │                           │                 │ block5b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6a_expand_conv (Conv2D)  │ (None, 32, 32, 672)       │          75,264 │ block5c_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6a_expand_bn             │ (None, 32, 32, 672)       │           2,688 │ block6a_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6a_expand_activation     │ (None, 32, 32, 672)       │               0 │ block6a_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6a_dwconv_pad            │ (None, 35, 35, 672)       │               0 │ block6a_expand_activation… │
# │ (ZeroPadding2D)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6a_dwconv                │ (None, 16, 16, 672)       │          16,800 │ block6a_dwconv_pad[0][0]   │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6a_bn                    │ (None, 16, 16, 672)       │           2,688 │ block6a_dwconv[0][0]       │
# ...
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6c_activation            │ (None, 16, 16, 1152)      │               0 │ block6c_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6c_se_squeeze            │ (None, 1152)              │               0 │ block6c_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6c_se_reshape (Reshape)  │ (None, 1, 1, 1152)        │               0 │ block6c_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6c_se_reduce (Conv2D)    │ (None, 1, 1, 48)          │          55,344 │ block6c_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6c_se_expand (Conv2D)    │ (None, 1, 1, 1152)        │          56,448 │ block6c_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6c_se_excite (Multiply)  │ (None, 16, 16, 1152)      │               0 │ block6c_activation[0][0],  │
# │                               │                           │                 │ block6c_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6c_project_conv (Conv2D) │ (None, 16, 16, 192)       │         221,184 │ block6c_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6c_project_bn            │ (None, 16, 16, 192)       │             768 │ block6c_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6c_drop (Dropout)        │ (None, 16, 16, 192)       │               0 │ block6c_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6c_add (Add)             │ (None, 16, 16, 192)       │               0 │ block6c_drop[0][0],        │
# │                               │                           │                 │ block6b_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_expand_conv (Conv2D)  │ (None, 16, 16, 1152)      │         221,184 │ block6c_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_expand_bn             │ (None, 16, 16, 1152)      │           4,608 │ block6d_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_expand_activation     │ (None, 16, 16, 1152)      │               0 │ block6d_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_dwconv                │ (None, 16, 16, 1152)      │          28,800 │ block6d_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_bn                    │ (None, 16, 16, 1152)      │           4,608 │ block6d_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_activation            │ (None, 16, 16, 1152)      │               0 │ block6d_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_se_squeeze            │ (None, 1152)              │               0 │ block6d_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_se_reshape (Reshape)  │ (None, 1, 1, 1152)        │               0 │ block6d_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_se_reduce (Conv2D)    │ (None, 1, 1, 48)          │          55,344 │ block6d_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_se_expand (Conv2D)    │ (None, 1, 1, 1152)        │          56,448 │ block6d_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_se_excite (Multiply)  │ (None, 16, 16, 1152)      │               0 │ block6d_activation[0][0],  │
# │                               │                           │                 │ block6d_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_project_conv (Conv2D) │ (None, 16, 16, 192)       │         221,184 │ block6d_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_project_bn            │ (None, 16, 16, 192)       │             768 │ block6d_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_drop (Dropout)        │ (None, 16, 16, 192)       │               0 │ block6d_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6d_add (Add)             │ (None, 16, 16, 192)       │               0 │ block6d_drop[0][0],        │
# │                               │                           │                 │ block6c_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_expand_conv (Conv2D)  │ (None, 16, 16, 1152)      │         221,184 │ block6d_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_expand_bn             │ (None, 16, 16, 1152)      │           4,608 │ block7a_expand_conv[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_expand_activation     │ (None, 16, 16, 1152)      │               0 │ block7a_expand_bn[0][0]    │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_dwconv                │ (None, 16, 16, 1152)      │          10,368 │ block7a_expand_activation… │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_bn                    │ (None, 16, 16, 1152)      │           4,608 │ block7a_dwconv[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_activation            │ (None, 16, 16, 1152)      │               0 │ block7a_bn[0][0]           │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_se_squeeze            │ (None, 1152)              │               0 │ block7a_activation[0][0]   │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_se_reshape (Reshape)  │ (None, 1, 1, 1152)        │               0 │ block7a_se_squeeze[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_se_reduce (Conv2D)    │ (None, 1, 1, 48)          │          55,344 │ block7a_se_reshape[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_se_expand (Conv2D)    │ (None, 1, 1, 1152)        │          56,448 │ block7a_se_reduce[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_se_excite (Multiply)  │ (None, 16, 16, 1152)      │               0 │ block7a_activation[0][0],  │
# │                               │                           │                 │ block7a_se_expand[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_project_conv (Conv2D) │ (None, 16, 16, 320)       │         368,640 │ block7a_se_excite[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7a_project_bn            │ (None, 16, 16, 320)       │           1,280 │ block7a_project_conv[0][0] │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ top_conv (Conv2D)             │ (None, 16, 16, 1280)      │         409,600 │ block7a_project_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ top_bn (BatchNormalization)   │ (None, 16, 16, 1280)      │           5,120 │ top_conv[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ top_activation (Activation)   │ (None, 16, 16, 1280)      │               0 │ top_bn[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_6 (Conv2D)             │ (None, 16, 16, 512)       │       5,898,752 │ top_activation[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d_5               │ (None, 32, 32, 512)       │               0 │ conv2d_6[0][0]             │
# │ (UpSampling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_4 (Concatenate)   │ (None, 32, 32, 1184)      │               0 │ up_sampling2d_5[0][0],     │
# │                               │                           │                 │ block6a_expand_activation… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_7 (Conv2D)             │ (None, 32, 32, 256)       │       2,728,192 │ concatenate_4[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d_6               │ (None, 64, 64, 256)       │               0 │ conv2d_7[0][0]             │
# │ (UpSampling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_5 (Concatenate)   │ (None, 64, 64, 496)       │               0 │ up_sampling2d_6[0][0],     │
# │                               │                           │                 │ block4a_expand_activation… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_8 (Conv2D)             │ (None, 64, 64, 128)       │         571,520 │ concatenate_5[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d_7               │ (None, 128, 128, 128)     │               0 │ conv2d_8[0][0]             │
# │ (UpSampling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_6 (Concatenate)   │ (None, 128, 128, 272)     │               0 │ up_sampling2d_7[0][0],     │
# │                               │                           │                 │ block3a_expand_activation… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_9 (Conv2D)             │ (None, 128, 128, 64)      │         156,736 │ concatenate_6[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d_8               │ (None, 256, 256, 64)      │               0 │ conv2d_9[0][0]             │
# │ (UpSampling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_7 (Concatenate)   │ (None, 256, 256, 160)     │               0 │ up_sampling2d_8[0][0],     │
# │                               │                           │                 │ block2a_expand_activation… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_10 (Conv2D)            │ (None, 256, 256, 32)      │          46,112 │ concatenate_7[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d_9               │ (None, 512, 512, 32)      │               0 │ conv2d_10[0][0]            │
# │ (UpSampling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_11 (Conv2D)            │ (None, 512, 512, 24)      │           6,936 │ up_sampling2d_9[0][0]      │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 13,457,819 (51.34 MB)
#  Trainable params: 9,408,248 (35.89 MB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
vgg16_unet.output_shape
# Out:
# (None, 512, 512, 24)

# %%
# pip install graphviz

# %%
# pip install pydot

# %%
# from IPython.display import SVG
# from tensorflow.keras.utils import model_to_dot

# SVG(model_to_dot(vgg16_unet).create(prog='dot', format='svg'))
# plot_model(vgg16_unet, to_file='vgg16_unet_plot.png', show_shapes=True, show_layer_names=True, expand_nested=True)

# %%
from tensorflow.keras.callbacks import LambdaCallback
class DebugBatchCallback(tf.keras.callbacks.Callback):
    def __init__(self):
        super().__init__()  # Initialize the base Callback class
    
    def on_batch_end(self, batch, logs=None):
        # Safely get the 'loss' and 'accuracy' with a default value
        loss = logs.get('loss', 'N/A')
        accuracy = logs.get('accuracy', 'N/A')
        
        # Check if loss and accuracy are floats before formatting
        if isinstance(loss, float):
            loss_str = f"{loss:.4f}"
        else:
            loss_str = str(loss)
            print("h")

        if isinstance(accuracy, float):
            accuracy_str = f"{accuracy:.4f}"
        else:
            accuracy_str = str(accuracy)
        

        # Print batch number, loss, and accuracy (if available)
        print(f"Batch {batch + 1} - Loss: {loss_str}, Accuracy: {accuracy_str}")
        
        # Example of accessing the model (if needed)
        first_layer_weights = self.model.layers[0].get_weights()
        print(f"    - First layer weights shape: {first_layer_weights[0].shape}")
db=DebugBatchCallback()        
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.0001, 20)

lr_scheduler = LearningRateScheduler(
    exponential_decay_fn,
    verbose=1
)

checkpoint = ModelCheckpoint(
    filepath = 'vgg16_unet_model.keras',
    save_best_only = True, 
#     save_weights_only = False,
    monitor = 'loss', 
    mode = 'auto', 
    verbose = 1
)

earlystop = EarlyStopping(
    monitor = 'loss', 
    min_delta = 0.001, 
    patience = 6, 
    mode = 'auto', 
    verbose = 1,
    restore_best_weights = True
)


csvlogger = CSVLogger(
    filename= "model_training_csv.log",
    separator = ",",
    append = False
)
class timeshistory(tf.keras.callbacks.Callback):
    def __init__(self, file_path="epoch_times.txt"):
        super(timeshistory, self).__init__()
        self.file_path = file_path  # Custom file path for saving the times

    def on_train_begin(self, logs=None):
        self.epoch_times = []  # Initialize a list to store times for each epoch

    def on_epoch_begin(self, epoch, logs=None):
        self.start_time = time.time()  # Record the start time of the epoch

    def on_epoch_end(self, epoch, logs=None):
        epoch_duration = time.time() - self.start_time  # Calculate the duration of the epoch
        self.epoch_times.append(epoch_duration)  # Append to the list

    def on_train_end(self, logs=None):
        # Ensure the directory exists
        os.makedirs(os.path.dirname(self.file_path), exist_ok=True)
        
        # Store the epoch times list in the specified file path
        with open(self.file_path, "w") as file:
            file.write(str(self.epoch_times))
        print(f"Epoch times saved to '{self.file_path}'.")
times_callback = timeshistory(file_path='/home/pranav/DeepLearning/100epochswithouttraining/resnettimes.txt')
callbacks = [checkpoint, csvlogger, lr_scheduler]
with open("/home/pranav/DeepLearning/new.txt","a") as wr:
    wr.write("The eigth")

# %%
print(train_images)
print(train_masks)
# print(val_images)
# print(masksval)
# Out:
# /home/pranav/DeepLearning/train_images
# /home/pranav/DeepLearning/train_masks

# %%
print("hh")
# Out:
# hh

# %%
steps_per_epoch=200
history = vgg16_unet.fit(
    TrainAugmentGenerator(train_images_dir = train_images, train_masks_dir = train_masks,batch_sizess=8, target_sizess = (512, 512)), 
    steps_per_epoch=steps_per_epoch,
    epochs = 100,
    callbacks=callbacks,
    verbose=1

)
# Out:
# Found 1600 images belonging to 1 classes.
# Found 1600 images belonging to 1 classes.
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731414774.697558 1510312 service.cc:148] XLA service 0x7f0c08008450 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731414774.697607 1510312 service.cc:156]   StreamExecutor device (0): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# I0000 00:00:1731414774.697611 1510312 service.cc:156]   StreamExecutor device (1): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# I0000 00:00:1731414774.697614 1510312 service.cc:156]   StreamExecutor device (2): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# I0000 00:00:1731414774.697617 1510312 service.cc:156]   StreamExecutor device (3): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# I0000 00:00:1731414774.697621 1510312 service.cc:156]   StreamExecutor device (4): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# I0000 00:00:1731414774.697624 1510312 service.cc:156]   StreamExecutor device (5): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# I0000 00:00:1731414774.697626 1510312 service.cc:156]   StreamExecutor device (6): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# 2024-11-12 18:02:55.314316: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1731414777.561086 1510312 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1731414779.964676 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414780.207844 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414780.410744 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414780.601790 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Could not load symbol cuFuncGetName. Error: /lib/x86_64-linux-gnu/libcuda.so.1: undefined symbol: cuFuncGetName
# E0000 00:00:1731414781.201511 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414781.368969 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414781.536580 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414781.917865 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414782.105941 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414782.284323 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414782.450875 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414783.073114 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414783.236302 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414783.399851 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414784.367496 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414784.541677 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414785.352020 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414785.536349 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414786.904793 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414787.076051 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414793.620631 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414793.801744 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414794.006950 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414794.193762 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414794.721908 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414794.908721 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414795.098175 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414795.266284 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414795.434255 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414796.474895 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414796.679983 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414796.897492 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414797.116805 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2024-11-12 18:03:17.239870: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng4{} for conv (f32[8,144,129,129]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,144,131,131]{3,2,1,0}, f32[144,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=144, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# E0000 00:00:1731414797.311154 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2024-11-12 18:03:17.321395: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.081614216s
# Trying algorithm eng4{} for conv (f32[8,144,129,129]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,144,131,131]{3,2,1,0}, f32[144,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=144, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# E0000 00:00:1731414799.471803 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414799.800125 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1731414800.068460 1510312 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/200 ━━━━━━━━━━━━━━━━━━━━ 3:51:41 70s/step - dice_coefficient: 0.0417 - loss: 3.3929
# I0000 00:00:1731414827.977104 1510312 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.1571 - loss: 2.5058
# Epoch 1: loss improved from inf to 1.88767, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 905s 4s/step - dice_coefficient: 0.1578 - loss: 2.5027 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 8.912509381337456e-05.
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.5369 - loss: 1.1590
# Epoch 2: loss improved from 1.88767 to 1.09323, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 836s 4s/step - dice_coefficient: 0.5370 - loss: 1.1586 - learning_rate: 8.9125e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 7.943282347242815e-05.
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.6142 - loss: 0.9366
# Epoch 3: loss improved from 1.09323 to 0.90198, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 838s 4s/step - dice_coefficient: 0.6142 - loss: 0.9365 - learning_rate: 7.9433e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 7.07945784384138e-05.
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.6596 - loss: 0.8083
# Epoch 4: loss improved from 0.90198 to 0.80182, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 838s 4s/step - dice_coefficient: 0.6596 - loss: 0.8083 - learning_rate: 7.0795e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 6.309573444801933e-05.
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.6898 - loss: 0.7319
# Epoch 5: loss improved from 0.80182 to 0.71156, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 831s 4s/step - dice_coefficient: 0.6898 - loss: 0.7318 - learning_rate: 6.3096e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 5.623413251903491e-05.
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.7140 - loss: 0.6640
# Epoch 6: loss improved from 0.71156 to 0.64748, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 836s 4s/step - dice_coefficient: 0.7140 - loss: 0.6639 - learning_rate: 5.6234e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 5.011872336272724e-05.
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.7369 - loss: 0.5997
# Epoch 7: loss improved from 0.64748 to 0.59105, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.7369 - loss: 0.5997 - learning_rate: 5.0119e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 4.4668359215096314e-05.
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.7473 - loss: 0.5731
# Epoch 8: loss improved from 0.59105 to 0.55699, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 838s 4s/step - dice_coefficient: 0.7474 - loss: 0.5730 - learning_rate: 4.4668e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 3.981071705534973e-05.
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.7661 - loss: 0.5250
# Epoch 9: loss improved from 0.55699 to 0.51325, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.7661 - loss: 0.5250 - learning_rate: 3.9811e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 3.548133892335755e-05.
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.7734 - loss: 0.5055
# Epoch 10: loss improved from 0.51325 to 0.49154, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 833s 4s/step - dice_coefficient: 0.7735 - loss: 0.5055 - learning_rate: 3.5481e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 3.1622776601683795e-05.
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.7856 - loss: 0.4768
# Epoch 11: loss improved from 0.49154 to 0.46164, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 837s 4s/step - dice_coefficient: 0.7856 - loss: 0.4767 - learning_rate: 3.1623e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 2.818382931264454e-05.
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.7979 - loss: 0.4489
# Epoch 12: loss improved from 0.46164 to 0.43976, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 837s 4s/step - dice_coefficient: 0.7979 - loss: 0.4489 - learning_rate: 2.8184e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 2.51188643150958e-05.
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8055 - loss: 0.4279
# Epoch 13: loss improved from 0.43976 to 0.42512, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.8055 - loss: 0.4279 - learning_rate: 2.5119e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 2.2387211385683396e-05.
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8093 - loss: 0.4179
# Epoch 14: loss improved from 0.42512 to 0.40334, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.8094 - loss: 0.4178 - learning_rate: 2.2387e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 1.99526231496888e-05.
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8236 - loss: 0.3875
# Epoch 15: loss improved from 0.40334 to 0.39185, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 835s 4s/step - dice_coefficient: 0.8235 - loss: 0.3875 - learning_rate: 1.9953e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 1.778279410038923e-05.
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8207 - loss: 0.3896
# Epoch 16: loss improved from 0.39185 to 0.38796, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.8208 - loss: 0.3896 - learning_rate: 1.7783e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 1.5848931924611134e-05.
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8283 - loss: 0.3748
# Epoch 17: loss improved from 0.38796 to 0.36891, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 836s 4s/step - dice_coefficient: 0.8283 - loss: 0.3748 - learning_rate: 1.5849e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 1.4125375446227545e-05.
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8355 - loss: 0.3569
# Epoch 18: loss improved from 0.36891 to 0.36103, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 835s 4s/step - dice_coefficient: 0.8355 - loss: 0.3569 - learning_rate: 1.4125e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 1.2589254117941673e-05.
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8344 - loss: 0.3601
# Epoch 19: loss improved from 0.36103 to 0.35969, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 835s 4s/step - dice_coefficient: 0.8344 - loss: 0.3601 - learning_rate: 1.2589e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 1.1220184543019637e-05.
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8397 - loss: 0.3469
# Epoch 20: loss improved from 0.35969 to 0.34979, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.8397 - loss: 0.3469 - learning_rate: 1.1220e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 1e-05.
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8450 - loss: 0.3364
# Epoch 21: loss improved from 0.34979 to 0.33824, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 833s 4s/step - dice_coefficient: 0.8450 - loss: 0.3364 - learning_rate: 1.0000e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 8.912509381337456e-06.
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8470 - loss: 0.3335
# Epoch 22: loss improved from 0.33824 to 0.33505, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 832s 4s/step - dice_coefficient: 0.8470 - loss: 0.3335 - learning_rate: 8.9125e-06
#
# Epoch 23: LearningRateScheduler setting learning rate to 7.943282347242815e-06.
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8473 - loss: 0.3315
# Epoch 23: loss improved from 0.33505 to 0.33344, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.8473 - loss: 0.3315 - learning_rate: 7.9433e-06
#
# Epoch 24: LearningRateScheduler setting learning rate to 7.079457843841382e-06.
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8451 - loss: 0.3369
# Epoch 24: loss improved from 0.33344 to 0.33041, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 835s 4s/step - dice_coefficient: 0.8451 - loss: 0.3369 - learning_rate: 7.0795e-06
#
# Epoch 25: LearningRateScheduler setting learning rate to 6.309573444801933e-06.
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8522 - loss: 0.3224
# Epoch 25: loss improved from 0.33041 to 0.32768, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 833s 4s/step - dice_coefficient: 0.8522 - loss: 0.3224 - learning_rate: 6.3096e-06
#
# Epoch 26: LearningRateScheduler setting learning rate to 5.623413251903491e-06.
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8466 - loss: 0.3323
# Epoch 26: loss did not improve from 0.32768
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.8466 - loss: 0.3323 - learning_rate: 5.6234e-06
#
# Epoch 27: LearningRateScheduler setting learning rate to 5.011872336272723e-06.
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8506 - loss: 0.3273
# Epoch 27: loss improved from 0.32768 to 0.32654, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 841s 4s/step - dice_coefficient: 0.8506 - loss: 0.3273 - learning_rate: 5.0119e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 4.466835921509631e-06.
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8558 - loss: 0.3103
# Epoch 28: loss improved from 0.32654 to 0.31593, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 835s 4s/step - dice_coefficient: 0.8557 - loss: 0.3103 - learning_rate: 4.4668e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 3.981071705534973e-06.
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8506 - loss: 0.3225
# Epoch 29: loss did not improve from 0.31593
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 833s 4s/step - dice_coefficient: 0.8506 - loss: 0.3225 - learning_rate: 3.9811e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 3.5481338923357555e-06.
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8548 - loss: 0.3102
# Epoch 30: loss improved from 0.31593 to 0.31413, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 839s 4s/step - dice_coefficient: 0.8548 - loss: 0.3102 - learning_rate: 3.5481e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 3.16227766016838e-06.
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8573 - loss: 0.3064
# Epoch 31: loss improved from 0.31413 to 0.30697, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 837s 4s/step - dice_coefficient: 0.8573 - loss: 0.3064 - learning_rate: 3.1623e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.818382931264454e-06.
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8538 - loss: 0.3177
# Epoch 32: loss improved from 0.30697 to 0.30638, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 837s 4s/step - dice_coefficient: 0.8539 - loss: 0.3176 - learning_rate: 2.8184e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.5118864315095797e-06.
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8586 - loss: 0.3045
# Epoch 33: loss did not improve from 0.30638
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 839s 4s/step - dice_coefficient: 0.8586 - loss: 0.3045 - learning_rate: 2.5119e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 2.2387211385683405e-06.
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8562 - loss: 0.3094
# Epoch 34: loss did not improve from 0.30638
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 836s 4s/step - dice_coefficient: 0.8562 - loss: 0.3094 - learning_rate: 2.2387e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.99526231496888e-06.
# Epoch 35/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8617 - loss: 0.2975
# Epoch 35: loss improved from 0.30638 to 0.30499, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 839s 4s/step - dice_coefficient: 0.8617 - loss: 0.2975 - learning_rate: 1.9953e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.7782794100389231e-06.
# Epoch 36/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8551 - loss: 0.3156
# Epoch 36: loss did not improve from 0.30499
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 835s 4s/step - dice_coefficient: 0.8551 - loss: 0.3156 - learning_rate: 1.7783e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 1.5848931924611134e-06.
# Epoch 37/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8624 - loss: 0.2950
# Epoch 37: loss improved from 0.30499 to 0.30151, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 835s 4s/step - dice_coefficient: 0.8624 - loss: 0.2950 - learning_rate: 1.5849e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.4125375446227544e-06.
# Epoch 38/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8603 - loss: 0.3003
# Epoch 38: loss improved from 0.30151 to 0.30056, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 835s 4s/step - dice_coefficient: 0.8604 - loss: 0.3003 - learning_rate: 1.4125e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.2589254117941678e-06.
# Epoch 39/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8618 - loss: 0.2987
# Epoch 39: loss did not improve from 0.30056
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 831s 4s/step - dice_coefficient: 0.8618 - loss: 0.2987 - learning_rate: 1.2589e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.1220184543019637e-06.
# Epoch 40/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8607 - loss: 0.3010
# Epoch 40: loss improved from 0.30056 to 0.30044, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 830s 4s/step - dice_coefficient: 0.8607 - loss: 0.3010 - learning_rate: 1.1220e-06
#
# Epoch 41: LearningRateScheduler setting learning rate to 1.0000000000000002e-06.
# Epoch 41/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8610 - loss: 0.3013
# Epoch 41: loss did not improve from 0.30044
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 832s 4s/step - dice_coefficient: 0.8610 - loss: 0.3013 - learning_rate: 1.0000e-06
#
# Epoch 42: LearningRateScheduler setting learning rate to 8.912509381337461e-07.
# Epoch 42/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8585 - loss: 0.3045
# Epoch 42: loss did not improve from 0.30044
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 833s 4s/step - dice_coefficient: 0.8585 - loss: 0.3045 - learning_rate: 8.9125e-07
#
# Epoch 43: LearningRateScheduler setting learning rate to 7.943282347242815e-07.
# Epoch 43/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8643 - loss: 0.2922
# Epoch 43: loss improved from 0.30044 to 0.29947, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 838s 4s/step - dice_coefficient: 0.8643 - loss: 0.2923 - learning_rate: 7.9433e-07
#
# Epoch 44: LearningRateScheduler setting learning rate to 7.079457843841381e-07.
# Epoch 44/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8629 - loss: 0.2948
# Epoch 44: loss did not improve from 0.29947
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.8628 - loss: 0.2949 - learning_rate: 7.0795e-07
#
# Epoch 45: LearningRateScheduler setting learning rate to 6.309573444801931e-07.
# Epoch 45/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8609 - loss: 0.2997
# Epoch 45: loss improved from 0.29947 to 0.29862, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 838s 4s/step - dice_coefficient: 0.8609 - loss: 0.2997 - learning_rate: 6.3096e-07
#
# Epoch 46: LearningRateScheduler setting learning rate to 5.623413251903492e-07.
# Epoch 46/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8590 - loss: 0.3046
# Epoch 46: loss improved from 0.29862 to 0.29678, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 835s 4s/step - dice_coefficient: 0.8590 - loss: 0.3045 - learning_rate: 5.6234e-07
#
# Epoch 47: LearningRateScheduler setting learning rate to 5.011872336272726e-07.
# Epoch 47/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8628 - loss: 0.2973
# Epoch 47: loss did not improve from 0.29678
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 829s 4s/step - dice_coefficient: 0.8628 - loss: 0.2973 - learning_rate: 5.0119e-07
#
# Epoch 48: LearningRateScheduler setting learning rate to 4.4668359215096306e-07.
# Epoch 48/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8592 - loss: 0.3086
# Epoch 48: loss did not improve from 0.29678
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 835s 4s/step - dice_coefficient: 0.8592 - loss: 0.3086 - learning_rate: 4.4668e-07
#
# Epoch 49: LearningRateScheduler setting learning rate to 3.9810717055349745e-07.
# Epoch 49/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8621 - loss: 0.2975
# Epoch 49: loss improved from 0.29678 to 0.29449, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 837s 4s/step - dice_coefficient: 0.8621 - loss: 0.2975 - learning_rate: 3.9811e-07
#
# Epoch 50: LearningRateScheduler setting learning rate to 3.5481338923357537e-07.
# Epoch 50/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8609 - loss: 0.3011
# Epoch 50: loss did not improve from 0.29449
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 832s 4s/step - dice_coefficient: 0.8609 - loss: 0.3011 - learning_rate: 3.5481e-07
#
# Epoch 51: LearningRateScheduler setting learning rate to 3.1622776601683797e-07.
# Epoch 51/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8618 - loss: 0.2984
# Epoch 51: loss did not improve from 0.29449
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 832s 4s/step - dice_coefficient: 0.8618 - loss: 0.2984 - learning_rate: 3.1623e-07
#
# Epoch 52: LearningRateScheduler setting learning rate to 2.8183829312644554e-07.
# Epoch 52/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8638 - loss: 0.2940
# Epoch 52: loss improved from 0.29449 to 0.29432, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 838s 4s/step - dice_coefficient: 0.8638 - loss: 0.2940 - learning_rate: 2.8184e-07
#
# Epoch 53: LearningRateScheduler setting learning rate to 2.51188643150958e-07.
# Epoch 53/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8638 - loss: 0.2951
# Epoch 53: loss improved from 0.29432 to 0.29293, saving model to vgg16_unet_model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.8638 - loss: 0.2951 - learning_rate: 2.5119e-07
#
# Epoch 54: LearningRateScheduler setting learning rate to 2.2387211385683404e-07.
# Epoch 54/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8633 - loss: 0.2958
# Epoch 54: loss did not improve from 0.29293
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.8633 - loss: 0.2958 - learning_rate: 2.2387e-07
#
# Epoch 55: LearningRateScheduler setting learning rate to 1.995262314968879e-07.
# Epoch 55/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8632 - loss: 0.2942
# Epoch 55: loss did not improve from 0.29293
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.8632 - loss: 0.2942 - learning_rate: 1.9953e-07
#
# Epoch 56: LearningRateScheduler setting learning rate to 1.778279410038923e-07.
# Epoch 56/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8608 - loss: 0.3012
# Epoch 56: loss did not improve from 0.29293
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 831s 4s/step - dice_coefficient: 0.8608 - loss: 0.3012 - learning_rate: 1.7783e-07
#
# Epoch 57: LearningRateScheduler setting learning rate to 1.5848931924611143e-07.
# Epoch 57/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8630 - loss: 0.2968
# Epoch 57: loss did not improve from 0.29293
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 836s 4s/step - dice_coefficient: 0.8630 - loss: 0.2968 - learning_rate: 1.5849e-07
#
# Epoch 58: LearningRateScheduler setting learning rate to 1.4125375446227541e-07.
# Epoch 58/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8617 - loss: 0.2983
# Epoch 58: loss did not improve from 0.29293
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 836s 4s/step - dice_coefficient: 0.8617 - loss: 0.2983 - learning_rate: 1.4125e-07
#
# Epoch 59: LearningRateScheduler setting learning rate to 1.2589254117941678e-07.
# Epoch 59/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.8668 - loss: 0.2847
# Epoch 59: loss did not improve from 0.29293
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - dice_coefficient: 0.8667 - loss: 0.2848 - learning_rate: 1.2589e-07
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 53.
# Epoch times saved to '/home/pranav/DeepLearning/100epochswithouttraining/resnettimes.txt'.

# %%
vgg16_unet.save('/home/pranav/DeepLearning/100epochswithouttraining/efficientbb.keras')

# %%
with open('home/pranav/DeepLearning/100epochswithouttraining/efficientbb', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 with open('home/pranav/DeepLearning/100epochswithouttraining/trainHistoryresNetPranav', 'wb') as file_pi:
#       2     pickle.dump(history.history, file_pi)
#
# File ~/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'home/pranav/DeepLearning/100epochswithouttraining/trainHistoryresNetPranav'

# %% [markdown]
# fig, ax = plt.subplots(1, 3, figsize=(30, 5))
# ax = ax.ravel()
# metrics = ['Dice Coefficient', 'Loss', 'Learning Rate']
#
# for i, met in enumerate(['dice_coefficient','loss','learning_rate']):
#     if met != 'lr':
#         ax[i].plot(history.history[met], 'o-')
#         #ax[i].plot(history.history['val_' + met], 'o-')
#         ax[i].set_title('{} vs Epochs'.format(metrics[i]), fontsize=16)
#         ax[i].set_xlabel('Epochs')
#         ax[i].set_ylabel(metrics[i])
#         ax[i].set_xticks(np.arange(1,3,2))
#         ax[i].legend(['Train', 'Validation'])
#         ax[i].xaxis.grid(True, color = "lightgray", linewidth = "0.8", linestyle = "-")
#         ax[i].yaxis.grid(True, color = "lightgray", linewidth = "0.8", linestyle = "-")
#     else:
#         ax[i].plot(history.history[met], 'o-')
#         ax[i].set_title('{} vs Epochs'.format(metrics[i]), fontsize=16)
#         ax[i].set_xlabel('Epochs')
#         ax[i].set_ylabel(metrics[i])
#         ax[i].set_xticks(np.arange(1,3,2))
#         ax[i].xaxis.grid(True, color = "lightgray", linewidth = "0.8", linestyle = "-")
#         ax[i].yaxis.grid(True, color = "lightgray", linewidth = "0.8", linestyle = "-")
#
# plt.savefig('model_metrics_plot.png', facecolor= 'w',transparent= False, bbox_inches= 'tight', dpi= 150)

# %%
#vgg16_unet.load_weights("./vgg16_unet_model.keras")

# %%
# testing_gen = ValAugmentGenerator(val_images_dr = val_images, masksvaldr = masksval, target_sizess = (512, 512))

# %%
# batch_img,batch_mask = ( "C:/Users/prana/Deep Learning - Segmentation/val_train_images/another/aug_1_000.jpg"  ,"C:/Users/prana/Deep Learning - Segmentation/masksvalimages/another/aug_1_000.png" )
# image_path = "C:/Users/prana/Deep Learning - Segmentation/val_train_images/another/aug_1_001.jpg" 
# img = cv2.imread(image_path)

# # Step 2: Resize and preprocess the image
# input_shape = (512, 512)  # Example input size for your model
# img_resized = cv2.resize(img, input_shape)
# img_normalized = img_resized / 255.0  # Normalize to [0, 1]
# img_batch = np.expand_dims(img_normalized, axis=0)  # Add batch dimension

# image_path = "C:/Users/prana/Deep Learning - Segmentation/masksvalimages/another/aug_1_001.png"
# img = cv2.imread(image_path)

# # Step 2: Resize and preprocess the image
# input_shape = (512, 512)  # Example input size for your model
# img_resized = cv2.resize(img, input_shape)
# img_normalized = img_resized / 255.0  # Normalize to [0, 1]
# img_mask = np.expand_dims(img_normalized, axis=0)  # Add batch dimension

# print(img_batch.shape)

# pred_all= vgg16_unet.predict(img_batch)
# np.shape(pred_all)
    

# fig = plt.figure(figsize=(20,8))

# ax1 = fig.add_subplot(1,3,1)
# ax1.imshow(np.squeeze(img_batch))
# ax1.title.set_text('Original Image')
# ax1.grid(False)

# ax2 = fig.add_subplot(1,3,2)
# ax2.set_title('Ground Truth Mask')
# img_mask=np.squeeze(img_mask)
# ax2.imshow(onehot_to_rgb(img_mask,id2code))
# ax2.grid(False)

# ax3 = fig.add_subplot(1,3,3)
# ax3.set_title('Predicted Mask')
# pred_all=np.squeeze(pred_all)           
# ax3.imshow(onehot_to_rgb(pred_all,id2code))
# ax3.grid(False)


# plt.show()

# %%
# !zip -r predictions.zip './predictions/'
